# %%
import boto3

BUCKET = 'mybackmu'
FILE_TO_READ = 'ExchangeRate'
client = boto3.client('s3',
                       aws_access_key_id='AKIA3VCQT2N3MGR5DJRB',
                       aws_secret_access_key='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'
                     )
result = client.get_object(Bucket=BUCKET, Key=FILE_TO_READ) 
text = result["Body"].read().decode()
print(text)
# Out:
# r030,txt,rate,cc,exchangedate
# 36,Австралійський долар,15.9946,AUD,02.03.2020
# 124,Канадський долар,18.3002,CAD,02.03.2020
# 156,Юань Женьмiньбi,3.5199,CNY,02.03.2020
# 191,Куна,3.6122,HRK,02.03.2020
# 203,Чеська крона,1.0624,CZK,02.03.2020
# 208,Данська крона,3.6106,DKK,02.03.2020
# 344,Гонконгівський долар,3.1548,HKD,02.03.2020
# 348,Форинт,0.079931,HUF,02.03.2020
# 356,Індійська рупія,0.34075,INR,02.03.2020
# 360,Рупія,0.0017221,IDR,02.03.2020
# 376,Новий ізраїльський шекель,7.0946,ILS,02.03.2020
# 392,Єна,0.22628,JPY,02.03.2020
# 398,Теньге,0.064422,KZT,02.03.2020
# 410,Вона,0.020237,KRW,02.03.2020
# 484,Мексиканське песо,1.2424,MXN,02.03.2020
# 498,Молдовський лей,1.3837,MDL,02.03.2020
# 554,Новозеландський долар,15.3343,NZD,02.03.2020
# 578,Норвезька крона,2.5961,NOK,02.03.2020
# 643,Російський рубль,0.36626,RUB,02.03.2020
# 682,Саудівський рiял,6.5547,SAR,02.03.2020
# 702,Сінгапурський долар,17.626,SGD,02.03.2020
# 710,Ренд,1.5777,ZAR,02.03.2020
# ...
